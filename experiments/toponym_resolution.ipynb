# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pandas as pd

# Add "../" to path to import utils
sys.path.insert(0, os.path.abspath(os.path.pardir))
from geoparser import preparation, recogniser, ranking, linking

# %%
dataset = "lwm"  # "hipe" or "lwm"

# Candidate selection approach, options are:
# * perfectmatch
# * partialmatch
# * levenshtein
# * deezymatch
cand_select_method = "deezymatch"

# Toponym resolution approach, options are:
# * mostpopular
# * contextualized
# * reldisamb:relcs # REL disambiguation with their candidates (our mentions)
# * reldisamb:lwmcs # REL disambiguation with our candidates (our mentions)
top_res_method = "mostpopular"
# top_res_method = "reldisamb:lwmcs:relv"
# top_res_method = "reldisamb:relcs"
# top_res_method = "reldisamb:lwmcs:dist"
# top_res_method = "reldisamb:lwmcs:relvdist"
# top_res_method = "gnn"

# %%
# --------------------------------------
# Instantiate the recogniser:
myner = recogniser.Recogniser(
    method="lwm",  # NER method
    model_name="blb_lwm-ner",  # NER model name prefix (will have suffixes appended)
    model=None,  # We'll store the NER model here
    pipe=None,  # We'll store the NER pipeline here
    base_model="/resources/models/bert/bert_1760_1900/",  # Base model to fine-tune
    train_dataset="outputs/data/lwm/ner_df_train.json",  # Training set (part of overall training set)
    test_dataset="outputs/data/lwm/ner_df_dev.json",  # Test set (part of overall training set)
    output_model_path="outputs/models/",  # Path where the NER model is or will be stored
    training_args={
        "learning_rate": 5e-5,
        "batch_size": 16,
        "num_train_epochs": 4,
        "weight_decay": 0.01,
    },
    overwrite_training=False,  # Set to True if you want to overwrite model if existing
    do_test=False,  # Set to True if you want to train on test mode
    training_tagset="fine",  # Options are: "coarse" or "fine"
)

# %%
# --------------------------------------
# Instantiate the ranker:
myranker = ranking.Ranker(
    method=cand_select_method,
    resources_path="/resources/wikidata/",
    mentions_to_wikidata=dict(),
    deezy_parameters={
        # Paths and filenames of DeezyMatch models and data:
        "dm_path": "/resources/develop/mcollardanuy/toponym-resolution/experiments/outputs/deezymatch/",
        "dm_cands": "wkdtalts",
        "dm_model": "ocr_avgpool",
        "dm_output": "deezymatch_on_the_fly",
        # Ranking measures:
        "ranking_metric": "faiss",
        "selection_threshold": 10,
        "num_candidates": 2,
        "search_size": 2,
        "use_predict": False,
        "verbose": False,
    },
)

# %%
# --------------------------------------
# Instantiate the linker:
mylinker = linking.Linker(
    method=top_res_method,
    resources_path="/resources/wikidata/",
    linking_resources=dict(),
    base_model="/resources/models/bert/bert_1760_1900/",  # Base model for vector extraction
    rel_params={"base_path": "/resources/rel_db/", "wiki_version": "wiki_2019/"},
    gnn_params={
        "level": "sentence_id",
        "max_distance": 200,
        "similarity_threshold": 0.7,
        "model_path": "/resources/develop/mcollardanuy/toponym-resolution/experiments/outputs/gnn_models/",
    },
    overwrite_training=False,
)

# %%
# --------------------------------------
# Instantiate the experiment:
experiment = preparation.Experiment(
    dataset=dataset,
    data_path="outputs/data/",
    dataset_df=pd.DataFrame(),
    results_path="outputs/results/",
    myner=myner,
    myranker=myranker,
    mylinker=mylinker,
    overwrite_processing=False,  # If True, do data processing, else load existing processing, if exists.
    processed_data=dict(),  # Dictionary where we'll keep the processed data for the experiments.
    test_split="test",  # "dev" while experimenting, "test" when running final experiments.
    rel_experiments=False,  # False if we're not interested in running the different experiments with REL, True otherwise.
)

# %%
# Print experiment information:
print(experiment)
print(myner)
print(myranker)
print(mylinker)
# Out:
# Data processing in the LWM dataset.
# * Overwrite processing: False
# * Experiments run on the >>> test <<< set.
#
#
# >>> Toponym recogniser:
#     * Method: lwm
#     * Model name: blb_lwm-ner-fine
#     * Base model: /resources/models/bert/bert_1760_1900/
#     * Overwrite model if exists: False
#     * Train in test mode: False
#     * Training args: {'learning_rate': 5e-05, 'batch_size': 16, 'num_train_epochs': 4, 'weight_decay': 0.01}
#     * Training tagset: fine
#
# >>> Candidate selection:
# 	* Method: deezymatch
#
# >>> Entity Linking:
# 	* Method: gnn
# 	* Overwrite training: False
# 	* Linking resources:

# %%
# Load processed data if existing:
experiment.processed_data = experiment.load_data()

# %%
# Perform data postprocessing:
experiment.processed_data = experiment.prepare_data()
# Out:
# Data already postprocessed and loaded!

# %%
mylinker.linking_resources = mylinker.load_resources()
# Out:
#   > Loading wikidata entity and instance embeddings.
#   > Mapping wikidata ids to instance ids.
# 929854it [00:37, 24790.48it/s]
#   > Loading mentions to wikidata mapping.
#   > Mapping coordinates to wikidata ids.

# %%
# Do the linking experiments:
experiment.linking_experiments()
# Out:
#   0%|          | 0/1991 [00:00<?, ?it/s]/home/mcollardanuy/.cache/pypoetry/virtualenvs/resolution-aSDWKgS4-py3.9/lib/python3.9/site-packages/torch_geometric/utils/convert.py:178: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
#   data[key] = torch.tensor(value)
# 100%|██████████| 1991/1991 [01:53<00:00, 17.56it/s]
# Number of training nodes tensor(7904)
# Number of dev nodes tensor(3902)
# Number of test nodes tensor(0)
#
#
# Number of nodes: 11806
# Number of edges: 95980
# Average node degree: 8.13
# Number of training nodes: 7904
# Training node label rate: 0.67
# Has isolated nodes: False
# Has self-loops: False
# Is undirected: True
# Saving model in:  /resources/develop/mcollardanuy/toponym-resolution/experiments/outputs/gnn_models/best_model_originalsplit
# Epoch 1 Training loss : 0.6933 Validation F1 :,0.0000
# Epoch 2 Training loss : 0.6804 Validation F1 :,0.0000
# Epoch 3 Training loss : 0.6706 Validation F1 :,0.0000
# Epoch 4 Training loss : 0.6594 Validation F1 :,0.0000
# Epoch 5 Training loss : 0.6496 Validation F1 :,0.0000
# Epoch 6 Training loss : 0.6455 Validation F1 :,0.1147
# Saving new best model with f1=0.1147
# Epoch 7 Training loss : 0.6306 Validation F1 :,0.4165
# Saving new best model with f1=0.4165
# Epoch 8 Training loss : 0.6094 Validation F1 :,0.4564
# Saving new best model with f1=0.4564
# Epoch 9 Training loss : 0.5941 Validation F1 :,0.4512
# Epoch 10 Training loss : 0.5850 Validation F1 :,0.4411
# Epoch 11 Training loss : 0.5811 Validation F1 :,0.4500
# Epoch 12 Training loss : 0.5667 Validation F1 :,0.4652
# Saving new best model with f1=0.4652
# Epoch 13 Training loss : 0.5690 Validation F1 :,0.4760
# Saving new best model with f1=0.4760
# Epoch 14 Training loss : 0.5581 Validation F1 :,0.4716
# Epoch 15 Training loss : 0.5498 Validation F1 :,0.4822
# Saving new best model with f1=0.4822
# Epoch 16 Training loss : 0.5412 Validation F1 :,0.5277
# Saving new best model with f1=0.5277
# Epoch 17 Training loss : 0.5351 Validation F1 :,0.5325
# Saving new best model with f1=0.5325
# Epoch 18 Training loss : 0.5237 Validation F1 :,0.5520
# Saving new best model with f1=0.5520
# Epoch 19 Training loss : 0.5177 Validation F1 :,0.5587
# Saving new best model with f1=0.5587
# Epoch 20 Training loss : 0.5203 Validation F1 :,0.5512
# Epoch 21 Training loss : 0.5114 Validation F1 :,0.6010
# Saving new best model with f1=0.6010
# Epoch 22 Training loss : 0.5036 Validation F1 :,0.6078
# Saving new best model with f1=0.6078
# Epoch 23 Training loss : 0.4958 Validation F1 :,0.6250
# Saving new best model with f1=0.6250
# Epoch 24 Training loss : 0.4892 Validation F1 :,0.5911
# Epoch 25 Training loss : 0.4869 Validation F1 :,0.6037
# Epoch 26 Training loss : 0.4818 Validation F1 :,0.5978
# Epoch 27 Training loss : 0.4735 Validation F1 :,0.5874
# Epoch 28 Training loss : 0.4692 Validation F1 :,0.5698
# Epoch 29 Training loss : 0.4612 Validation F1 :,0.5921
# Epoch 30 Training loss : 0.4558 Validation F1 :,0.6149
# Epoch 31 Training loss : 0.4515 Validation F1 :,0.6199
# Epoch 32 Training loss : 0.4500 Validation F1 :,0.6136
# Epoch 33 Training loss : 0.4456 Validation F1 :,0.6339
# Saving new best model with f1=0.6339
# Epoch 34 Training loss : 0.4374 Validation F1 :,0.6349
# Saving new best model with f1=0.6349
# Epoch 35 Training loss : 0.4316 Validation F1 :,0.6323
# Epoch 36 Training loss : 0.4278 Validation F1 :,0.6478
# Saving new best model with f1=0.6478
# Epoch 37 Training loss : 0.4227 Validation F1 :,0.6646
# Saving new best model with f1=0.6646
# Epoch 38 Training loss : 0.4173 Validation F1 :,0.6635
# Epoch 39 Training loss : 0.4118 Validation F1 :,0.6820
# Saving new best model with f1=0.6820
# Epoch 40 Training loss : 0.4034 Validation F1 :,0.6805
# Epoch 41 Training loss : 0.4061 Validation F1 :,0.6719
# Epoch 42 Training loss : 0.3990 Validation F1 :,0.6790
# Epoch 43 Training loss : 0.3927 Validation F1 :,0.6837
# Saving new best model with f1=0.6837
# Epoch 44 Training loss : 0.3871 Validation F1 :,0.6889
# Saving new best model with f1=0.6889
# Epoch 45 Training loss : 0.3833 Validation F1 :,0.6977
# Saving new best model with f1=0.6977
# Epoch 46 Training loss : 0.3826 Validation F1 :,0.6897
# Epoch 47 Training loss : 0.3800 Validation F1 :,0.6982
# Saving new best model with f1=0.6982
# Epoch 48 Training loss : 0.3766 Validation F1 :,0.7001
# Saving new best model with f1=0.7001
# Epoch 49 Training loss : 0.3778 Validation F1 :,0.7035
# Saving new best model with f1=0.7035
# Epoch 50 Training loss : 0.3745 Validation F1 :,0.7214
# Saving new best model with f1=0.7214
# Epoch 51 Training loss : 0.3625 Validation F1 :,0.7404
# Saving new best model with f1=0.7404
# Epoch 52 Training loss : 0.3612 Validation F1 :,0.7465
# Saving new best model with f1=0.7465
# Epoch 53 Training loss : 0.3567 Validation F1 :,0.7219
# Epoch 54 Training loss : 0.3528 Validation F1 :,0.7165
# Epoch 55 Training loss : 0.3539 Validation F1 :,0.7225
# Epoch 56 Training loss : 0.3514 Validation F1 :,0.7550
# Saving new best model with f1=0.7550
# Epoch 57 Training loss : 0.3479 Validation F1 :,0.7517
# Epoch 58 Training loss : 0.3385 Validation F1 :,0.7463
# Epoch 59 Training loss : 0.3388 Validation F1 :,0.7261
# Epoch 60 Training loss : 0.3371 Validation F1 :,0.7356
# Epoch 61 Training loss : 0.3370 Validation F1 :,0.7450
# Epoch 62 Training loss : 0.3371 Validation F1 :,0.7252
# Epoch 63 Training loss : 0.3245 Validation F1 :,0.7702
# Saving new best model with f1=0.7702
# Epoch 64 Training loss : 0.3289 Validation F1 :,0.7613
# Epoch 65 Training loss : 0.3321 Validation F1 :,0.7215
# Epoch 66 Training loss : 0.3208 Validation F1 :,0.7722
# Saving new best model with f1=0.7722
# Epoch 67 Training loss : 0.3248 Validation F1 :,0.7901
# Saving new best model with f1=0.7901
# Epoch 68 Training loss : 0.3196 Validation F1 :,0.7625
# Epoch 69 Training loss : 0.3108 Validation F1 :,0.7610
# Epoch 70 Training loss : 0.3202 Validation F1 :,0.7326
# Epoch 71 Training loss : 0.3058 Validation F1 :,0.7550
# Epoch 72 Training loss : 0.3070 Validation F1 :,0.7716
# Epoch 73 Training loss : 0.3009 Validation F1 :,0.8134
# Saving new best model with f1=0.8134
# Epoch 74 Training loss : 0.3027 Validation F1 :,0.8006
# Epoch 75 Training loss : 0.3003 Validation F1 :,0.7649
# Epoch 76 Training loss : 0.2929 Validation F1 :,0.7658
# Epoch 77 Training loss : 0.2973 Validation F1 :,0.7708
# Epoch 78 Training loss : 0.2904 Validation F1 :,0.7957
# Epoch 79 Training loss : 0.2896 Validation F1 :,0.7857
# Epoch 80 Training loss : 0.2828 Validation F1 :,0.7920
# Epoch 81 Training loss : 0.2855 Validation F1 :,0.7792
# Epoch 82 Training loss : 0.2843 Validation F1 :,0.7650
# Epoch 83 Training loss : 0.2787 Validation F1 :,0.7979
# Epoch 84 Training loss : 0.2765 Validation F1 :,0.8154
# Saving new best model with f1=0.8154
# Epoch 85 Training loss : 0.2712 Validation F1 :,0.8124
# Epoch 86 Training loss : 0.2688 Validation F1 :,0.7895
# Epoch 87 Training loss : 0.2698 Validation F1 :,0.7722
# Epoch 88 Training loss : 0.2634 Validation F1 :,0.7671
# Epoch 89 Training loss : 0.2672 Validation F1 :,0.7837
# Epoch 90 Training loss : 0.2645 Validation F1 :,0.7981
# Epoch 91 Training loss : 0.2595 Validation F1 :,0.8074
# Epoch 92 Training loss : 0.2560 Validation F1 :,0.7830
# Epoch 93 Training loss : 0.2579 Validation F1 :,0.7719
# Epoch 94 Training loss : 0.2559 Validation F1 :,0.8036
# Epoch 95 Training loss : 0.2534 Validation F1 :,0.8066
# Epoch 96 Training loss : 0.2513 Validation F1 :,0.8209
# Saving new best model with f1=0.8209
# Epoch 97 Training loss : 0.2490 Validation F1 :,0.8075
# Epoch 98 Training loss : 0.2519 Validation F1 :,0.7721
# Epoch 99 Training loss : 0.2763 Validation F1 :,0.7951
# Epoch 100 Training loss : 0.2708 Validation F1 :,0.8072
# Epoch 101 Training loss : 0.2700 Validation F1 :,0.8379
# Saving new best model with f1=0.8379
# Epoch 102 Training loss : 0.2643 Validation F1 :,0.8681
# Saving new best model with f1=0.8681
# Epoch 103 Training loss : 0.2476 Validation F1 :,0.8420
# Epoch 104 Training loss : 0.2608 Validation F1 :,0.7716
# Epoch 105 Training loss : 0.2667 Validation F1 :,0.7845
# Epoch 106 Training loss : 0.2429 Validation F1 :,0.8291
# Epoch 107 Training loss : 0.2513 Validation F1 :,0.8095
# Epoch 108 Training loss : 0.2446 Validation F1 :,0.8398
# Epoch 109 Training loss : 0.2420 Validation F1 :,0.8599
# Epoch 110 Training loss : 0.2481 Validation F1 :,0.8496
# Epoch 111 Training loss : 0.2327 Validation F1 :,0.8221
# Epoch 112 Training loss : 0.2387 Validation F1 :,0.7884
# Epoch 113 Training loss : 0.2319 Validation F1 :,0.8244
# Epoch 114 Training loss : 0.2324 Validation F1 :,0.8316
# Epoch 115 Training loss : 0.2252 Validation F1 :,0.8345
# Epoch 116 Training loss : 0.2290 Validation F1 :,0.8185
# Epoch 117 Training loss : 0.2209 Validation F1 :,0.8325
# Epoch 118 Training loss : 0.2239 Validation F1 :,0.8359
# Epoch 119 Training loss : 0.2141 Validation F1 :,0.8204
# Epoch 120 Training loss : 0.2163 Validation F1 :,0.8043
# Epoch 121 Training loss : 0.2116 Validation F1 :,0.8234
# Epoch 122 Training loss : 0.2148 Validation F1 :,0.8292
# Epoch 123 Training loss : 0.2115 Validation F1 :,0.8192
# Epoch 124 Training loss : 0.2036 Validation F1 :,0.8295
# Epoch 125 Training loss : 0.2046 Validation F1 :,0.8302
# Epoch 126 Training loss : 0.2008 Validation F1 :,0.8257
# Epoch 127 Training loss : 0.2016 Validation F1 :,0.8148
# Epoch 128 Training loss : 0.1938 Validation F1 :,0.8314
# Epoch 129 Training loss : 0.1922 Validation F1 :,0.8269
# Epoch 130 Training loss : 0.1922 Validation F1 :,0.8252
# Epoch 131 Training loss : 0.1961 Validation F1 :,0.8333
# Epoch 132 Training loss : 0.1938 Validation F1 :,0.8208
# Epoch 133 Training loss : 0.1918 Validation F1 :,0.8305
# Epoch 134 Training loss : 0.1913 Validation F1 :,0.8284
# Epoch 135 Training loss : 0.1872 Validation F1 :,0.8125
# Epoch 136 Training loss : 0.1846 Validation F1 :,0.8231
# Epoch 137 Training loss : 0.1833 Validation F1 :,0.8243
# Epoch 138 Training loss : 0.1828 Validation F1 :,0.8198
# Epoch 139 Training loss : 0.1831 Validation F1 :,0.8229
# Epoch 140 Training loss : 0.1769 Validation F1 :,0.8249
# Epoch 141 Training loss : 0.1781 Validation F1 :,0.8218
# Epoch 142 Training loss : 0.1794 Validation F1 :,0.8307
# Epoch 143 Training loss : 0.1755 Validation F1 :,0.8157
# Epoch 144 Training loss : 0.1796 Validation F1 :,0.8282
# Epoch 145 Training loss : 0.1716 Validation F1 :,0.8283
# Epoch 146 Training loss : 0.1707 Validation F1 :,0.8279
# Epoch 147 Training loss : 0.1754 Validation F1 :,0.8272
# Epoch 148 Training loss : 0.1832 Validation F1 :,0.7979
# Epoch 149 Training loss : 0.1848 Validation F1 :,0.8366
# Epoch 150 Training loss : 0.1766 Validation F1 :,0.8436
# Epoch 151 Training loss : 0.1745 Validation F1 :,0.8374
# Epoch 152 Training loss : 0.1757 Validation F1 :,0.8256
# Epoch 153 Training loss : 0.1687 Validation F1 :,0.8277
# Epoch 154 Training loss : 0.1732 Validation F1 :,0.8218
# Epoch 155 Training loss : 0.1699 Validation F1 :,0.8176
# Epoch 156 Training loss : 0.1674 Validation F1 :,0.8244
# Epoch 157 Training loss : 0.1675 Validation F1 :,0.8387
# Epoch 158 Training loss : 0.1614 Validation F1 :,0.8408
# Epoch 159 Training loss : 0.1629 Validation F1 :,0.8298
# Epoch 160 Training loss : 0.1666 Validation F1 :,0.8163
# Epoch 161 Training loss : 0.1614 Validation F1 :,0.8217
# Epoch 162 Training loss : 0.1561 Validation F1 :,0.8282
# Epoch 163 Training loss : 0.1571 Validation F1 :,0.8244
# Epoch 164 Training loss : 0.1572 Validation F1 :,0.8188
# Epoch 165 Training loss : 0.1542 Validation F1 :,0.8267
# Epoch 166 Training loss : 0.1509 Validation F1 :,0.8228
# Epoch 167 Training loss : 0.1534 Validation F1 :,0.8160
# Epoch 168 Training loss : 0.1573 Validation F1 :,0.8268
# Epoch 169 Training loss : 0.1509 Validation F1 :,0.8315
# Epoch 170 Training loss : 0.1492 Validation F1 :,0.8270
# Epoch 171 Training loss : 0.1498 Validation F1 :,0.8312
# Epoch 172 Training loss : 0.1486 Validation F1 :,0.8269
# Epoch 173 Training loss : 0.1492 Validation F1 :,0.8177
# Epoch 174 Training loss : 0.1442 Validation F1 :,0.8188
# Epoch 175 Training loss : 0.1441 Validation F1 :,0.8211
# Epoch 176 Training loss : 0.1439 Validation F1 :,0.8236
# Epoch 177 Training loss : 0.1457 Validation F1 :,0.8214
# Epoch 178 Training loss : 0.1433 Validation F1 :,0.8241
# Epoch 179 Training loss : 0.1461 Validation F1 :,0.8220
# Epoch 180 Training loss : 0.1440 Validation F1 :,0.8259
# Epoch 181 Training loss : 0.1400 Validation F1 :,0.8252
# Epoch 182 Training loss : 0.1431 Validation F1 :,0.8235
# Epoch 183 Training loss : 0.1380 Validation F1 :,0.8263
# Epoch 184 Training loss : 0.1369 Validation F1 :,0.8217
# Epoch 185 Training loss : 0.1401 Validation F1 :,0.8214
# Epoch 186 Training loss : 0.1383 Validation F1 :,0.8248
# Epoch 187 Training loss : 0.1361 Validation F1 :,0.8258
# Epoch 188 Training loss : 0.1357 Validation F1 :,0.8214
# Epoch 189 Training loss : 0.1373 Validation F1 :,0.8246
# Epoch 190 Training loss : 0.1318 Validation F1 :,0.8212
# Epoch 191 Training loss : 0.1329 Validation F1 :,0.8229
# Epoch 192 Training loss : 0.1309 Validation F1 :,0.8257
# Epoch 193 Training loss : 0.1334 Validation F1 :,0.8288
# Epoch 194 Training loss : 0.1312 Validation F1 :,0.8335
# Epoch 195 Training loss : 0.1286 Validation F1 :,0.8342
# Epoch 196 Training loss : 0.1311 Validation F1 :,0.8335
# Epoch 197 Training loss : 0.1305 Validation F1 :,0.8301
# Epoch 198 Training loss : 0.1317 Validation F1 :,0.8276
# Epoch 199 Training loss : 0.1281 Validation F1 :,0.8296
# Epoch 200 Training loss : 0.1282 Validation F1 :,0.8312
# Epoch 201 Training loss : 0.1294 Validation F1 :,0.8326
# Epoch 202 Training loss : 0.1285 Validation F1 :,0.8371
# Epoch 203 Training loss : 0.1235 Validation F1 :,0.8318
# Epoch 204 Training loss : 0.1266 Validation F1 :,0.8270
# Epoch 205 Training loss : 0.1273 Validation F1 :,0.8313
# Epoch 206 Training loss : 0.1261 Validation F1 :,0.8342
# Epoch 207 Training loss : 0.1233 Validation F1 :,0.8323
# Epoch 208 Training loss : 0.1279 Validation F1 :,0.8315
# Epoch 209 Training loss : 0.1275 Validation F1 :,0.8378
# Epoch 210 Training loss : 0.1244 Validation F1 :,0.8321
# Epoch 211 Training loss : 0.1214 Validation F1 :,0.8342
# Epoch 212 Training loss : 0.1259 Validation F1 :,0.8374
# Epoch 213 Training loss : 0.1243 Validation F1 :,0.8327
# Epoch 214 Training loss : 0.1245 Validation F1 :,0.8404
# Epoch 215 Training loss : 0.1242 Validation F1 :,0.8368
# Epoch 216 Training loss : 0.1285 Validation F1 :,0.8211
# Epoch 217 Training loss : 0.1235 Validation F1 :,0.8348
# Epoch 218 Training loss : 0.1271 Validation F1 :,0.8387
# Epoch 219 Training loss : 0.1288 Validation F1 :,0.8477
# Epoch 220 Training loss : 0.1231 Validation F1 :,0.8504
# Epoch 221 Training loss : 0.1236 Validation F1 :,0.8448
# Epoch 222 Training loss : 0.1300 Validation F1 :,0.8424
# Epoch 223 Training loss : 0.1232 Validation F1 :,0.8435
# Epoch 224 Training loss : 0.1267 Validation F1 :,0.8415
# Epoch 225 Training loss : 0.1263 Validation F1 :,0.8429
# Epoch 226 Training loss : 0.1225 Validation F1 :,0.8505
# Epoch 227 Training loss : 0.1231 Validation F1 :,0.8382
# Epoch 228 Training loss : 0.1259 Validation F1 :,0.8362
# Epoch 229 Training loss : 0.1261 Validation F1 :,0.8420
# Epoch 230 Training loss : 0.1214 Validation F1 :,0.8499
# Epoch 231 Training loss : 0.1224 Validation F1 :,0.8475
# Epoch 232 Training loss : 0.1225 Validation F1 :,0.8440
# Epoch 233 Training loss : 0.1232 Validation F1 :,0.8447
# Epoch 234 Training loss : 0.1234 Validation F1 :,0.8463
# Epoch 235 Training loss : 0.1214 Validation F1 :,0.8526
# Epoch 236 Training loss : 0.1217 Validation F1 :,0.8528
# Epoch 237 Training loss : 0.1166 Validation F1 :,0.8457
# Epoch 238 Training loss : 0.1178 Validation F1 :,0.8513
# Epoch 239 Training loss : 0.1172 Validation F1 :,0.8471
# Epoch 240 Training loss : 0.1193 Validation F1 :,0.8487
# Epoch 241 Training loss : 0.1156 Validation F1 :,0.8530
# Epoch 242 Training loss : 0.1147 Validation F1 :,0.8476
# Epoch 243 Training loss : 0.1220 Validation F1 :,0.8439
# Epoch 244 Training loss : 0.1170 Validation F1 :,0.8463
# Epoch 245 Training loss : 0.1133 Validation F1 :,0.8559
# Epoch 246 Training loss : 0.1142 Validation F1 :,0.8594
# Epoch 247 Training loss : 0.1120 Validation F1 :,0.8532
# Epoch 248 Training loss : 0.1144 Validation F1 :,0.8505
# Epoch 249 Training loss : 0.1136 Validation F1 :,0.8476
# Epoch 250 Training loss : 0.1140 Validation F1 :,0.8464
# Epoch 251 Training loss : 0.1127 Validation F1 :,0.8460
# Epoch 252 Training loss : 0.1127 Validation F1 :,0.8488
# Epoch 253 Training loss : 0.1123 Validation F1 :,0.8509
# Epoch 254 Training loss : 0.1161 Validation F1 :,0.8481
# Epoch 255 Training loss : 0.1126 Validation F1 :,0.8484
# Epoch 256 Training loss : 0.1112 Validation F1 :,0.8491
# Epoch 257 Training loss : 0.1134 Validation F1 :,0.8488
# Epoch 258 Training loss : 0.1125 Validation F1 :,0.8486
# Epoch 259 Training loss : 0.1152 Validation F1 :,0.8407
# Epoch 260 Training loss : 0.1133 Validation F1 :,0.8536
# Epoch 261 Training loss : 0.1140 Validation F1 :,0.8559
# Epoch 262 Training loss : 0.1120 Validation F1 :,0.8447
# Epoch 263 Training loss : 0.1103 Validation F1 :,0.8404
# Epoch 264 Training loss : 0.1116 Validation F1 :,0.8423
# Epoch 265 Training loss : 0.1104 Validation F1 :,0.8391
# Epoch 266 Training loss : 0.1100 Validation F1 :,0.8399
# Epoch 267 Training loss : 0.1070 Validation F1 :,0.8448
# Epoch 268 Training loss : 0.1126 Validation F1 :,0.8478
# Epoch 269 Training loss : 0.1086 Validation F1 :,0.8446
# Epoch 270 Training loss : 0.1129 Validation F1 :,0.8451
# Epoch 271 Training loss : 0.1063 Validation F1 :,0.8498
# Epoch 272 Training loss : 0.1079 Validation F1 :,0.8528
# Epoch 273 Training loss : 0.1082 Validation F1 :,0.8411
# Epoch 274 Training loss : 0.1099 Validation F1 :,0.8480
# Epoch 275 Training loss : 0.1069 Validation F1 :,0.8402
# Epoch 276 Training loss : 0.1049 Validation F1 :,0.8350
# Epoch 277 Training loss : 0.1024 Validation F1 :,0.8431
# Epoch 278 Training loss : 0.1063 Validation F1 :,0.8449
# Epoch 279 Training loss : 0.1042 Validation F1 :,0.8467
# Epoch 280 Training loss : 0.1060 Validation F1 :,0.8373
# Epoch 281 Training loss : 0.1047 Validation F1 :,0.8436
# Epoch 282 Training loss : 0.1035 Validation F1 :,0.8448
# Epoch 283 Training loss : 0.1052 Validation F1 :,0.8500
# Epoch 284 Training loss : 0.1027 Validation F1 :,0.8501
# Epoch 285 Training loss : 0.1032 Validation F1 :,0.8457
# Epoch 286 Training loss : 0.1005 Validation F1 :,0.8380
# Epoch 287 Training loss : 0.1025 Validation F1 :,0.8422
# Epoch 288 Training loss : 0.1018 Validation F1 :,0.8382
# Epoch 289 Training loss : 0.1003 Validation F1 :,0.8469
# Epoch 290 Training loss : 0.1015 Validation F1 :,0.8567
# Epoch 291 Training loss : 0.0993 Validation F1 :,0.8469
# Epoch 292 Training loss : 0.1014 Validation F1 :,0.8437
# Epoch 293 Training loss : 0.1002 Validation F1 :,0.8450
# Epoch 294 Training loss : 0.0994 Validation F1 :,0.8454
# Epoch 295 Training loss : 0.1017 Validation F1 :,0.8469
# Epoch 296 Training loss : 0.1012 Validation F1 :,0.8475
# Epoch 297 Training loss : 0.1022 Validation F1 :,0.8475
# Epoch 298 Training loss : 0.1017 Validation F1 :,0.8438
# Epoch 299 Training loss : 0.1025 Validation F1 :,0.8460
# Epoch 300 Training loss : 0.1009 Validation F1 :,0.8432
# Epoch 301 Training loss : 0.1031 Validation F1 :,0.8434
# Epoch 302 Training loss : 0.0992 Validation F1 :,0.8432
# Epoch 303 Training loss : 0.0970 Validation F1 :,0.8395
# Epoch 304 Training loss : 0.0999 Validation F1 :,0.8450
# Epoch 305 Training loss : 0.1011 Validation F1 :,0.8465
# Epoch 306 Training loss : 0.1000 Validation F1 :,0.8454
# Epoch 307 Training loss : 0.0949 Validation F1 :,0.8451
# Epoch 308 Training loss : 0.0978 Validation F1 :,0.8402
# Epoch 309 Training loss : 0.0975 Validation F1 :,0.8406
# Epoch 310 Training loss : 0.0968 Validation F1 :,0.8394
# Epoch 311 Training loss : 0.0986 Validation F1 :,0.8473
# Epoch 312 Training loss : 0.0953 Validation F1 :,0.8530
# Epoch 313 Training loss : 0.0968 Validation F1 :,0.8519
# Epoch 314 Training loss : 0.0997 Validation F1 :,0.8509
# Epoch 315 Training loss : 0.0960 Validation F1 :,0.8459
# Epoch 316 Training loss : 0.0935 Validation F1 :,0.8409
# Epoch 317 Training loss : 0.0943 Validation F1 :,0.8351
# Epoch 318 Training loss : 0.0974 Validation F1 :,0.8406
# Epoch 319 Training loss : 0.0974 Validation F1 :,0.8490
# Epoch 320 Training loss : 0.0997 Validation F1 :,0.8464
# Epoch 321 Training loss : 0.0973 Validation F1 :,0.8440
# Epoch 322 Training loss : 0.0950 Validation F1 :,0.8440
# Epoch 323 Training loss : 0.0928 Validation F1 :,0.8448
# Epoch 324 Training loss : 0.0935 Validation F1 :,0.8426
# Epoch 325 Training loss : 0.0953 Validation F1 :,0.8446
# Epoch 326 Training loss : 0.0956 Validation F1 :,0.8479
# Epoch 327 Training loss : 0.0980 Validation F1 :,0.8451
# Epoch 328 Training loss : 0.0968 Validation F1 :,0.8385
# Epoch 329 Training loss : 0.0965 Validation F1 :,0.8521
# Epoch 330 Training loss : 0.0939 Validation F1 :,0.8488
# Epoch 331 Training loss : 0.0967 Validation F1 :,0.8453
# Epoch 332 Training loss : 0.0927 Validation F1 :,0.8481
# Epoch 333 Training loss : 0.0936 Validation F1 :,0.8474
# Epoch 334 Training loss : 0.0915 Validation F1 :,0.8476
# Epoch 335 Training loss : 0.0951 Validation F1 :,0.8403
# Epoch 336 Training loss : 0.0936 Validation F1 :,0.8492
# Epoch 337 Training loss : 0.0919 Validation F1 :,0.8470
# Epoch 338 Training loss : 0.0907 Validation F1 :,0.8447
# Epoch 339 Training loss : 0.0910 Validation F1 :,0.8430
# Epoch 340 Training loss : 0.0925 Validation F1 :,0.8426
# Epoch 341 Training loss : 0.0918 Validation F1 :,0.8481
# Epoch 342 Training loss : 0.0935 Validation F1 :,0.8456
# Epoch 343 Training loss : 0.0920 Validation F1 :,0.8517
# Epoch 344 Training loss : 0.0932 Validation F1 :,0.8527
# Epoch 345 Training loss : 0.0904 Validation F1 :,0.8440
# Epoch 346 Training loss : 0.0894 Validation F1 :,0.8477
# Epoch 347 Training loss : 0.0888 Validation F1 :,0.8565
# Epoch 348 Training loss : 0.0907 Validation F1 :,0.8513
# Epoch 349 Training loss : 0.0914 Validation F1 :,0.8466
# Epoch 350 Training loss : 0.0901 Validation F1 :,0.8510
# Epoch 351 Training loss : 0.0901 Validation F1 :,0.8580
# Epoch 352 Training loss : 0.0880 Validation F1 :,0.8515
# Epoch 353 Training loss : 0.0916 Validation F1 :,0.8582
# Epoch 354 Training loss : 0.0920 Validation F1 :,0.8569
# Epoch 355 Training loss : 0.0894 Validation F1 :,0.8574
# Epoch 356 Training loss : 0.0890 Validation F1 :,0.8548
# Epoch 357 Training loss : 0.0891 Validation F1 :,0.8525
# Epoch 358 Training loss : 0.0913 Validation F1 :,0.8484
# Epoch 359 Training loss : 0.0872 Validation F1 :,0.8519
# Epoch 360 Training loss : 0.0896 Validation F1 :,0.8539
# Epoch 361 Training loss : 0.0895 Validation F1 :,0.8450
# Epoch 362 Training loss : 0.0893 Validation F1 :,0.8507
# Epoch 363 Training loss : 0.0868 Validation F1 :,0.8552
# Epoch 364 Training loss : 0.0867 Validation F1 :,0.8569
# Epoch 365 Training loss : 0.0859 Validation F1 :,0.8505
# Epoch 366 Training loss : 0.0886 Validation F1 :,0.8486
# Epoch 367 Training loss : 0.0900 Validation F1 :,0.8464
# Epoch 368 Training loss : 0.0882 Validation F1 :,0.8526
# Epoch 369 Training loss : 0.0887 Validation F1 :,0.8483
# Epoch 370 Training loss : 0.0903 Validation F1 :,0.8436
# Epoch 371 Training loss : 0.0888 Validation F1 :,0.8381
# Epoch 372 Training loss : 0.0892 Validation F1 :,0.8449
# Epoch 373 Training loss : 0.0880 Validation F1 :,0.8533
# Epoch 374 Training loss : 0.0880 Validation F1 :,0.8472
# Epoch 375 Training loss : 0.0888 Validation F1 :,0.8457
# Epoch 376 Training loss : 0.0867 Validation F1 :,0.8496
# Epoch 377 Training loss : 0.0890 Validation F1 :,0.8461
# Epoch 378 Training loss : 0.0919 Validation F1 :,0.8520
# Epoch 379 Training loss : 0.0879 Validation F1 :,0.8494
# Epoch 380 Training loss : 0.0906 Validation F1 :,0.8539
# Epoch 381 Training loss : 0.0889 Validation F1 :,0.8472
# Epoch 382 Training loss : 0.0874 Validation F1 :,0.8473
# Epoch 383 Training loss : 0.0862 Validation F1 :,0.8590
# Epoch 384 Training loss : 0.0868 Validation F1 :,0.8631
# Epoch 385 Training loss : 0.0864 Validation F1 :,0.8593
# Epoch 386 Training loss : 0.0857 Validation F1 :,0.8584
# Epoch 387 Training loss : 0.0860 Validation F1 :,0.8497
# Epoch 388 Training loss : 0.0832 Validation F1 :,0.8544
# Epoch 389 Training loss : 0.0862 Validation F1 :,0.8497
# Epoch 390 Training loss : 0.0860 Validation F1 :,0.8502
# Epoch 391 Training loss : 0.0854 Validation F1 :,0.8504
# Epoch 392 Training loss : 0.0867 Validation F1 :,0.8531
# Epoch 393 Training loss : 0.0848 Validation F1 :,0.8508
# Epoch 394 Training loss : 0.0858 Validation F1 :,0.8500
# Epoch 395 Training loss : 0.0899 Validation F1 :,0.8498
# Epoch 396 Training loss : 0.1202 Validation F1 :,0.8297
# Epoch 397 Training loss : 0.1334 Validation F1 :,0.8602
# Epoch 398 Training loss : 0.1186 Validation F1 :,0.8692
# Saving new best model with f1=0.8692
# Epoch 399 Training loss : 0.1240 Validation F1 :,0.8624
# Epoch 400 Training loss : 0.1318 Validation F1 :,0.8588
# Epoch 401 Training loss : 0.1246 Validation F1 :,0.8490
# Epoch 402 Training loss : 0.1185 Validation F1 :,0.8681
# Epoch 403 Training loss : 0.1227 Validation F1 :,0.8675
# Epoch 404 Training loss : 0.1228 Validation F1 :,0.8541
# Epoch 405 Training loss : 0.1179 Validation F1 :,0.8571
# Epoch 406 Training loss : 0.1188 Validation F1 :,0.8662
# Epoch 407 Training loss : 0.1136 Validation F1 :,0.8630
# Epoch 408 Training loss : 0.1093 Validation F1 :,0.8586
# Epoch 409 Training loss : 0.1116 Validation F1 :,0.8580
# Epoch 410 Training loss : 0.1082 Validation F1 :,0.8503
# Epoch 411 Training loss : 0.1092 Validation F1 :,0.8540
# Epoch 412 Training loss : 0.1025 Validation F1 :,0.8559
# Epoch 413 Training loss : 0.1057 Validation F1 :,0.8617
# Epoch 414 Training loss : 0.1040 Validation F1 :,0.8665
# Epoch 415 Training loss : 0.1016 Validation F1 :,0.8649
# Epoch 416 Training loss : 0.1037 Validation F1 :,0.8626
# Epoch 417 Training loss : 0.1033 Validation F1 :,0.8664
# Epoch 418 Training loss : 0.0996 Validation F1 :,0.8613
# Epoch 419 Training loss : 0.0980 Validation F1 :,0.8646
# Epoch 420 Training loss : 0.0979 Validation F1 :,0.8676
# Epoch 421 Training loss : 0.0972 Validation F1 :,0.8656
# Epoch 422 Training loss : 0.0982 Validation F1 :,0.8671
# Epoch 423 Training loss : 0.0944 Validation F1 :,0.8603
# Epoch 424 Training loss : 0.0964 Validation F1 :,0.8601
# Epoch 425 Training loss : 0.0970 Validation F1 :,0.8663
# Epoch 426 Training loss : 0.0943 Validation F1 :,0.8700
# Saving new best model with f1=0.8700
# Epoch 427 Training loss : 0.0928 Validation F1 :,0.8676
# Epoch 428 Training loss : 0.0902 Validation F1 :,0.8654
# Epoch 429 Training loss : 0.0962 Validation F1 :,0.8668
# Epoch 430 Training loss : 0.0891 Validation F1 :,0.8635
# Epoch 431 Training loss : 0.0931 Validation F1 :,0.8622
# Epoch 432 Training loss : 0.0923 Validation F1 :,0.8622
# Epoch 433 Training loss : 0.0921 Validation F1 :,0.8627
# Epoch 434 Training loss : 0.0940 Validation F1 :,0.8635
# Epoch 435 Training loss : 0.0876 Validation F1 :,0.8666
# Epoch 436 Training loss : 0.0903 Validation F1 :,0.8618
# Epoch 437 Training loss : 0.0908 Validation F1 :,0.8640
# Epoch 438 Training loss : 0.0866 Validation F1 :,0.8616
# Epoch 439 Training loss : 0.0898 Validation F1 :,0.8628
# Epoch 440 Training loss : 0.0904 Validation F1 :,0.8639
# Epoch 441 Training loss : 0.0883 Validation F1 :,0.8656
# Epoch 442 Training loss : 0.0877 Validation F1 :,0.8684
# Epoch 443 Training loss : 0.0886 Validation F1 :,0.8665
# Epoch 444 Training loss : 0.0895 Validation F1 :,0.8633
# Epoch 445 Training loss : 0.0875 Validation F1 :,0.8639
# Epoch 446 Training loss : 0.0852 Validation F1 :,0.8698
# Epoch 447 Training loss : 0.0858 Validation F1 :,0.8678
# Epoch 448 Training loss : 0.0839 Validation F1 :,0.8729
# Saving new best model with f1=0.8729
# Epoch 449 Training loss : 0.0848 Validation F1 :,0.8722
# Epoch 450 Training loss : 0.0861 Validation F1 :,0.8644
# Epoch 451 Training loss : 0.0850 Validation F1 :,0.8637
# Epoch 452 Training loss : 0.0838 Validation F1 :,0.8644
# Epoch 453 Training loss : 0.0828 Validation F1 :,0.8636
# Epoch 454 Training loss : 0.0858 Validation F1 :,0.8627
# Epoch 455 Training loss : 0.0867 Validation F1 :,0.8643
# Epoch 456 Training loss : 0.0830 Validation F1 :,0.8670
# Epoch 457 Training loss : 0.0846 Validation F1 :,0.8686
# Epoch 458 Training loss : 0.0861 Validation F1 :,0.8681
# Epoch 459 Training loss : 0.0833 Validation F1 :,0.8685
# Epoch 460 Training loss : 0.0841 Validation F1 :,0.8721
# Epoch 461 Training loss : 0.0819 Validation F1 :,0.8728
# Epoch 462 Training loss : 0.0840 Validation F1 :,0.8669
# Epoch 463 Training loss : 0.0833 Validation F1 :,0.8578
# Epoch 464 Training loss : 0.0874 Validation F1 :,0.8580
# Epoch 465 Training loss : 0.0852 Validation F1 :,0.8561
# Epoch 466 Training loss : 0.0800 Validation F1 :,0.8627
# Epoch 467 Training loss : 0.0812 Validation F1 :,0.8580
# Epoch 468 Training loss : 0.0799 Validation F1 :,0.8622
# Epoch 469 Training loss : 0.0858 Validation F1 :,0.8645
# Epoch 470 Training loss : 0.0798 Validation F1 :,0.8664
# Epoch 471 Training loss : 0.0823 Validation F1 :,0.8681
# Epoch 472 Training loss : 0.0802 Validation F1 :,0.8668
# Epoch 473 Training loss : 0.0798 Validation F1 :,0.8634
# Epoch 474 Training loss : 0.0805 Validation F1 :,0.8548
# Epoch 475 Training loss : 0.0792 Validation F1 :,0.8632
# Epoch 476 Training loss : 0.0807 Validation F1 :,0.8600
# Epoch 477 Training loss : 0.0783 Validation F1 :,0.8595
# Epoch 478 Training loss : 0.0799 Validation F1 :,0.8663
# Epoch 479 Training loss : 0.0806 Validation F1 :,0.8672
# Epoch 480 Training loss : 0.0796 Validation F1 :,0.8683
# Epoch 481 Training loss : 0.0791 Validation F1 :,0.8614
# Epoch 482 Training loss : 0.0798 Validation F1 :,0.8602
# Epoch 483 Training loss : 0.0853 Validation F1 :,0.8554
# Epoch 484 Training loss : 0.0790 Validation F1 :,0.8599
# Epoch 485 Training loss : 0.0800 Validation F1 :,0.8619
# Epoch 486 Training loss : 0.0775 Validation F1 :,0.8533
# Epoch 487 Training loss : 0.0825 Validation F1 :,0.8653
# Epoch 488 Training loss : 0.0795 Validation F1 :,0.8649
# Epoch 489 Training loss : 0.0787 Validation F1 :,0.8669
# Epoch 490 Training loss : 0.0788 Validation F1 :,0.8665
# Epoch 491 Training loss : 0.0770 Validation F1 :,0.8618
# Epoch 492 Training loss : 0.0794 Validation F1 :,0.8656
# Epoch 493 Training loss : 0.0770 Validation F1 :,0.8683
# Epoch 494 Training loss : 0.0787 Validation F1 :,0.8729
# Epoch 495 Training loss : 0.0789 Validation F1 :,0.8712
# Epoch 496 Training loss : 0.0781 Validation F1 :,0.8666
# Epoch 497 Training loss : 0.0754 Validation F1 :,0.8701
# Epoch 498 Training loss : 0.0750 Validation F1 :,0.8688
# Epoch 499 Training loss : 0.0783 Validation F1 :,0.8683
# /resources/develop/mcollardanuy/toponym-resolution/experiments/../geoparser/linking.py:230: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["matched"] = test_df.candidates.apply(lambda x: "_".join(x.keys()))
# 100%|██████████| 710/710 [00:46<00:00, 15.27it/s]
#   0%|          | 0/710 [00:00<?, ?it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   0%|          | 1/710 [00:00<03:11,  3.70it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   0%|          | 2/710 [00:00<04:40,  2.52it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   1%|          | 5/710 [00:00<01:40,  7.03it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   1%|▏         | 9/710 [00:01<00:55, 12.59it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   2%|▏         | 12/710 [00:01<00:44, 15.57it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   2%|▏         | 15/710 [00:01<00:41, 16.91it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   3%|▎         | 18/710 [00:01<01:00, 11.36it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   3%|▎         | 20/710 [00:01<01:00, 11.48it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid"] = "NIL"
# /resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:402: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_df["pred_wqid_score"] = 0.0
#   3%|▎         | 22/710 [00:02<01:16,  8.96it/s]/resources/develop/mcollardanuy/toponym-resolution/utils/gnn_method.py:401: SettingWithCopyWarning:
# ...
# LIverpool_Liverpool ('Q24826', 0.9840481)
# Ireland ('Q22890', 0.912736)
# Liverpool ('Q24826', 0.9840295)
# Ireland ('Q22890', 0.912736)
# Ireland ('Q22890', 0.912736)
# Manchester ('Q18125', 0.98005015)
# Blackburn ('Q188313', 0.96752596)
# Manchester ('Q18125', 0.98005015)
# England ('Q21', 0.95969176)
# Manchester ('Q18125', 0.98005015)
# Manchester ('Q18125', 0.98005015)
# Salford ('Q47952', 0.963194)
# Parkstone ('Q7138722', 0.79207635)
# Poole_Pole ('Q203349', 0.9796944)
# London ('Q84', 0.98430645)
# Blackfriars ('Q880829', 0.9591635)
# Devonshire ('Q23156', 0.92423224)
# Exeter ('Q134672', 0.9677308)
# Newton Abbot ('Q660484', 0.9841471)
# Devon ('Q23156', 0.9398634)
# Dorsetshire ('Q23159', 0.97866666)
# Isle of Portland ('Q774215', 0.94377136)
# Child Okeford ('Q2153905', 0.90663326)
# Isle of Portland ('Q774215', 0.89825684)
# Winchester ('Q172157', 0.9788426)
# Island of Guernsey ('Q3311985', 0.9259255)
# Great Britain ('Q23666', 0.96677077)
# Downing Street ('Q192687', 0.82868856)
# Leeds ('Q39121', 0.9789587)
# Calcutta ('Q1348', 0.9652568)
# India ('Q668', 0.9253493)
# Dorset ('Q23159', 0.9435475)
# Dorchester ('Q1024037', 0.52093434)
# Poole ('Q203349', 0.9791808)
# Weymouth ('Q661619', 0.9398047)
# LONDON ('Q84', 0.9791412)
# Vienna ('Q1741', 0.9889159)
# Britain ('Q145', 0.82453084)
# Egypt ('Q79', 0.9509911)
# Devonshire ('Q23156', 0.92423224)
# Exeter ('Q134672', 0.9677308)
# Exeter ('Q134672', 0.9722659)
# training college ('Q5146843', 0.54668844)
# Hyde_Heede ('Q2080165', 0.9627682)
# Baguley ('Q2879240', 0.88585424)
# Hyde ('Q2080165', 0.97881156)
# Manchester ('Q18125', 0.97909695)
# Cheshire ('Q23064', 0.8960125)
# Lancashire ('Q23077', 0.98927015)
# Cheshire ('Q23064', 0.98584205)
# Baguley ('Q2879240', 0.9399088)
# Chester ('Q170263', 0.9124484)
# Collegiate Church ('Q971811', 0.8224406)
# Preston ('Q184090', 0.71589977)
# Liverpool ('Q24826', 0.93825054)
# Warrington ('Q215733', 0.56110895)
# Chester ('Q170263', 0.9124484)
# Great Harwood ('Q2305059', 0.9279489)
# Blackburn ('Q188313', 0.97675896)
# Great Harwood ('Q2305059', 0.8663145)
# Collegiate Church ('Q971811', 0.8706393)
# Chorlton ('Q586414', 0.59894234)
# Hough End Hall ('Q15225919', 0.7914007)
# Chester ('Q170263', 0.9124484)
# Oldham ('Q202628', 0.9878128)
# Oldham ('Q202628', 0.9878128)
# Swansea ('Q23051', 0.9548742)
# south Nottinghamshire ('Q23092', 0.94637644)
# Nottingham ('Q41262', 0.98325104)
# Ludlow ('Q839811', 0.6948437)
# Bruges ('Q12994', 0.67009944)
# Bath ('Q22889', 0.97407156)
# Perth ('Q3183', 0.973865)
# Leith ('Q1018540', 0.9272575)
# Chard ('Q117810', 0.8509368)
# Chard ('Q117810', 0.95323)
# Winsham ('Q2332165', 0.9423705)
# Thorncombe ('Q1944795', 0.8641618)
# Chard ('Q117810', 0.8509368)
# LONDON ('Q84', 0.9791412)
# Malta ('Q233', 0.9531791)
# Bombay ('Q1156', 0.97597957)
# Zanzibar ('Q1774', 0.82255495)
# Africa ('Q15', 0.9877506)
# Africa ('Q15', 0.98717934)
# Bombay ('Q1156', 0.9780303)
# Bath ('Q22889', 0.9727423)
# London ('Q84', 0.9692342)
# Paris ('Q90', 0.9813658)
# LONDON ('Q84', 0.9791412)
# City ('Q23311', 0.93578845)
# South America ('Q18', 0.96507114)
# Brazil ('Q155', 0.9774161)
# Corfu ('Q121378', 0.95651)
# Missolonghi ('Q642810', 0.88659376)
# Lepanto ('Q165425', 0.95625836)
# Salona ('Q1258998', 0.599297)
# Athens ('Q1524', 0.9909977)
# Patras ('Q133123', 0.9757848)
# Tripolizza ('Q193409', 0.8695827)
# Napoli di Romania ('Q202337', 0.9473557)
# Ardwick ('Q2860767', 0.9292649)
# LONDON ('Q84', 0.9791412)
# Whitehall ('Q214820', 0.6147343)
# London ('Q84', 0.87704617)
# Berlin ('Q64', 0.9783839)
# Sicily_Sicilly ('Q1460', 0.9867067)
# Naples ('Q2634', 0.9858948)
# Dorsetshire ('Q23159', 0.9769646)
# Allington_Alkington ('Q4727713', 0.52698517)
# Bridport ('Q914040', 0.95833814)
# London ('Q84', 0.9731635)
# Bridport ('Q181428', 0.7930438)
# Exeter ('Q134672', 0.97386044)
